# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt
from sklearn import metrics

# %%
df=pd.read_csv('IRIS.csv')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
sns.scatterplot(x="sepal_length", y="sepal_width", data=df)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
plt.figure(figsize = (16,6))
sns.countplot(x="sepal_length", data=df, hue="species", palette = 'magma')
# Out:
# <Axes: xlabel='sepal_length', ylabel='count'>

# %%
#Conclusion: The density of Iris-setosa is mostly on the smaller end of sepal lengths while Iris-virginica's leangths are on the longer end of the graph.

# %%
plt.figure(figsize = (16,6))
sns.countplot(x="sepal_width", data=df, hue="species")
# Out:
# <Axes: xlabel='sepal_width', ylabel='count'>

# %%
#Conclusion: Iris-versicolor has the smaller widths while Iris-virginica has bigger widths for their petals.

# %%
sns.scatterplot(x="petal_length", y="petal_width", data=df)
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %%
plt.figure(figsize = (16,6))
sns.countplot(x="petal_length", data=df, hue="species", palette = 'Reds')
# Out:
# <Axes: xlabel='petal_length', ylabel='count'>

# %%
plt.figure(figsize = (16,6))
sns.countplot(x="petal_length", data=df, hue="species")
# Out:
# <Axes: xlabel='petal_length', ylabel='count'>

# %%
#conclusion: The smaller sizes are occupied by Iris-setosa, medium by Iris-versicolor, and the largest sizes are occupied for Iris-virginica.

# %%
sns.pairplot(df)
# Out:
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
X=df.drop(["species"], axis=1)
Y=df["species"]

# %%
X_train, X_test, Y_train, Y_test= train_test_split(X,Y, test_size=0.3, random_state=50)

# %%
lr=LogisticRegression()

# %%
lr.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
lr.score(X_train, Y_train)
# Out:
# 0.9809523809523809

# %%
Y_test_predictions=lr.predict(X_test)

# %%
Y_test_predictions
# Out:
# array(['Iris-versicolor', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-setosa',
#        'Iris-virginica'], dtype=object)

# %%
Y
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: species, Length: 150, dtype: object

# %%
Y_test
# Out:
# 88     Iris-versicolor
# 72     Iris-versicolor
# 20         Iris-setosa
# 16         Iris-setosa
# 147     Iris-virginica
# 140     Iris-virginica
# 113     Iris-virginica
# 23         Iris-setosa
# 12         Iris-setosa
# 68     Iris-versicolor
# 39         Iris-setosa
# 130     Iris-virginica
# 34         Iris-setosa
# 112     Iris-virginica
# 55     Iris-versicolor
# 25         Iris-setosa
# 82     Iris-versicolor
# 48         Iris-setosa
# 81     Iris-versicolor
# 77     Iris-versicolor
# 100     Iris-virginica
# 80     Iris-versicolor
# 14         Iris-setosa
# 131     Iris-virginica
# 86     Iris-versicolor
# 118     Iris-virginica
# 56     Iris-versicolor
# 54     Iris-versicolor
# 97     Iris-versicolor
# 143     Iris-virginica
# 125     Iris-virginica
# 98     Iris-versicolor
# 73     Iris-versicolor
# 144     Iris-virginica
# 21         Iris-setosa
# 3          Iris-setosa
# 59     Iris-versicolor
# 119     Iris-virginica
# 84     Iris-versicolor
# 7          Iris-setosa
# ...

# %%
training_data_accuracy=metrics.accuracy_score(Y_test, Y_test_predictions)
print(f"accuracy: {100*training_data_accuracy:.2f}%")
# Out:
# accuracy: 97.78%
